# %% [markdown]
# We are not doing this because the format of the data was extremely different from the question answering dataset.
# Original idea: See if we could improve on Berant and Liang (2015), but the dataset that they used (suggested in the Yao et al paper we "reimplemented") https://github.com/brmson/dataset-factoid-webquestions/blob/master/main/trainmodel.json was in a different format from the IFTT recipes. We explored modifying this to fit the format, but given many of the dependencies in the training data, it would appear that question-answering was a simpler task?? and we would have to make many adjustments to the algorithm.

# %%
import pickle

# %%
iftt = pickle.load(open("data/lam/toy_data_with_noisy_user_ans.pkl"))
# Out:
# /anaconda3/envs/cs285-proj/lib/python2.7/site-packages/sklearn/base.py:253: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.19.1 when using version 0.20.4. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
iftt['train']
# Out:
# [{'ids': [20327, 147, 75828],
#   'label_names': ['Date & Time',
#    'Every month on the',
#    'Google Calendar',
#    'Quick add event'],
#   'labels': [35, 231, 53, 229],
#   'pseudo_ask_labels': [1, 1, 1, 1],
#   'recipe_id': '9219',
#   'words': [u'\u53d1\u5de5\u8d44', u'&', u'\u62db\u884c\u8fd8\u6b3e\u65e5']},
#  {'ids': [649],
#   'label_names': ['Twitter', 'New tweet by you', 'Twitter', 'Post a tweet'],
#   'labels': [200, 598, 171, 209],
#   'pseudo_ask_labels': [1, 1, 1, 1],
#   'recipe_id': '162694',
#   'words': [u'6']},
#  {'ids': [172, 10, 20],
#   'label_names': ['SoundCloud',
#    'New public like',
#    'Tumblr',
#    'Create a text post'],
#   'labels': [177, 538, 170, 115],
#   'pseudo_ask_labels': [0, 1, 0, 1],
#   'recipe_id': '265951',
#   'words': [u'soundcloud', u'post', u'tumblr']},
#  {'ids': [232, 1275, 732],
#   'label_names': ['Nest Thermostat',
#    'Temperature drops below',
#    'Phone Call',
#    'Call my phone'],
#   'labels': [121, 768, 120, 79],
# ...

# %%
iftt['user_answers']
# Out:
# [{'500px': [[192]],
#   'ARTIK Cloud': [[78122, 675]],
#   'AT&T M2X': [[64, 147, 590, 6710]],
#   'Adafruit': [[4365]],
#   'Amazon Alexa': [[185, 214]],
#   'Android Battery': [[108, 509]],
#   'Android Device': [[108, 310]],
#   'Android Location': [[108, 305]],
#   'Android Phone Call': [[108, 86, 125]],
#   'Android Photos': [[108, 46]],
#   'Android SMS': [[108, 59]],
#   'Android Wear': [[108, 536]],
#   'AppZapp': [[7818]],
#   'Arlo': [[1811]],
#   'Assistant.ai': [[78122]],
#   'Automatic': [[582]],
#   'BMW Labs': [[1721, 5093]],
#   'Beeminder': [[1083]],
#   'Best Buy': [[258, 655]],
#   'Blogger': [[36]],
#   'BloomSky': [[4396]],
#   'Boxoh Package Tracking': [[12134, 954, 737]],
#   'Bttn': [[2768]],
#   'Buffer': [[54]],
#   'Caleo': [[12117]],
#   'Camio': [[6663]],
#   'Chain': [[6221]],
#   'Cisco Spark': [[3056, 1132]],
#   'Concur': [[18917]],
#   'Craigslist': [[179]],
#   'D-Link Motion Sensor': [[1991, 350, 994]],
# ...
